# %% [markdown]
# # a

# %%
n = 100

norms = rnorm(n)
norms

m = mean(norms)
m

s = sd(norms)
s

z = qnorm(.8)
z

left = m - (z * s / sqrt(n))
left
right = m + (z * s / sqrt(n))
right
# Out:
#   [1]  0.428349301  1.192710795  0.078209490 -0.109410669 -0.421056612
#   [6]  0.085912762 -1.755217099  0.178690251 -0.962872582 -0.261398205
#  [11]  1.433246422  2.056880407 -1.136665992 -1.153074161  0.739402171
#  [16]  0.346828980  0.467714917  0.178496031  0.981389747 -0.558161236
#  [21] -0.404601901  1.744545264 -1.125165805 -0.022220211 -0.693288142
#  [26]  0.101143269 -0.101499578 -0.592587368  0.854388341  0.083856188
#  [31]  0.091576141  1.551514593 -1.408289178  2.214305470 -0.724433382
#  [36]  0.568845242 -0.726406643 -0.332041882  0.009735709  0.563757873
#  [41]  1.899306465 -0.532327256 -0.445330363 -0.124822921  0.039212800
#  [46] -1.972114924  0.275431350 -1.460296487 -0.976477868  1.363213694
#  [51]  0.069971792  1.130166112 -1.204615991 -0.403380615  0.096641856
#  [56]  1.132404115  0.558287742 -0.802593555  0.023657755 -0.273390544
#  [61]  1.073725761 -1.131500205  0.490840310  0.022314920  0.158124884
# ...

# %% [markdown]
# ## since 0 is contained in the confidence interval, the mean for this set could be 0.

# %%
n = 100

norms = rnorm(n)
norms

m = mean(norms)
m

s = sd(norms)
s

z = qnorm(.8)
z

left = m - (z * s / sqrt(n))
left
right = m + (z * s / sqrt(n))
right
# Out:
#   [1] -0.71342885 -1.02803759  0.98452773 -1.17759950  0.19728433 -1.41022127
#   [7]  0.23693778 -1.22749271 -0.72399300  1.15112515  0.33648314  0.07737314
#  [13]  1.01078237 -0.22520479  0.50468645 -1.31268380 -0.09879139 -0.45911418
#  [19] -0.69820798 -1.71416185 -1.25348376 -0.52289715  0.31128587 -1.06373760
#  [25] -0.34520229  0.25306530 -0.52599122 -0.55171723 -0.37644362  0.53300761
#  [31]  1.32125915 -0.16212622  0.51130143 -0.61163852 -0.15933795 -0.46250082
#  [37]  0.14955457  0.45467366 -2.02541628  0.75826535  0.75970650  2.62010627
#  [43] -0.53820704  0.65796113 -1.17038809  0.09366396 -0.84881321 -0.24687892
#  [49] -0.59333668  1.32229682  0.21002335  1.15452700  0.98545278  1.38916745
#  [55]  0.21359315  1.53320550 -0.23944099 -0.41173909  1.14024654  1.85866387
#  [61]  1.66213105 -1.86828304  0.59596587 -0.20082351 -0.05868243 -0.47189774
#  [67] -0.25010063 -0.60865264 -1.25351675 -0.16908065  1.08763842 -0.76824118
# ...

# %%
n = 100

norms = rnorm(n)
norms

m = mean(norms)
m

s = sd(norms)
s

z = qnorm(.8)
z

left = m - (z * s / sqrt(n))
left
right = m + (z * s / sqrt(n))
right
# Out:
#   [1]  0.312037550  0.620318540 -0.957623911 -0.176885941 -0.579915016
#   [6]  0.660123152  0.549593409 -0.053567286 -1.070065765 -0.492084754
#  [11] -0.137629561  0.295302130 -2.848460485  0.291437472  1.493431492
#  [16] -0.265957031  0.297098624  0.615742860  0.301428315 -0.528591658
#  [21]  0.991045864  1.436089166  0.001989676  0.339752325  0.114005317
#  [26] -1.230138482  0.409594203 -0.310475317 -0.003215635  1.069625979
#  [31]  0.440921112  1.140918471  1.629563995 -0.344936888 -0.643640967
#  [36]  1.252983085  0.479888517 -0.541843889 -1.762497439 -1.284553550
#  [41]  1.688177788  1.896473581 -1.128395747  1.162300604  0.067612357
#  [46] -0.311207489  0.490388347  0.223556811 -0.333864849 -0.690575584
#  [51]  1.865678517 -2.017464412 -1.019430140  0.403801616  1.607547428
#  [56] -0.484775723  1.437227122  0.259949448  0.848731019 -0.173628286
#  [61] -0.301147297 -0.409958233  0.449167377  2.017643637  1.077550998
# ...

# %%
n = 100

norms = rnorm(n)
norms

m = mean(norms)
m

s = sd(norms)
s

z = qnorm(.8)
z

left = m - (z * s / sqrt(n))
left
right = m + (z * s / sqrt(n))
right
# Out:
#   [1] -1.01628165  0.47246218  0.00262735 -0.94243552 -0.04278414  0.03523876
#   [7]  1.38804140  2.13467421  1.53834509  0.99391627 -1.40899779 -1.16085024
#  [13] -0.56551663 -2.44193379  1.29393947 -1.12479101  0.69901360  0.75937778
#  [19] -1.42317428  0.31201598  0.29870150  0.09653169 -1.26953779  0.41739774
#  [25]  0.22263859 -0.27895155 -0.37925520  0.10003189 -0.84351846  0.27120958
#  [31] -1.67693070  1.03392093  0.52984397  0.99724969  0.95282884 -0.61354958
#  [37]  0.98593335  1.16001957  1.44122393 -0.11756097 -0.30487404 -0.37833644
#  [43]  0.55509183 -0.10609605  2.01453769 -0.55484360  0.51598649 -0.39191538
#  [49] -0.13130511  0.11928239  1.44189446  0.62582976  1.81764008  0.61050251
#  [55] -0.01026197 -0.36640638 -1.58867555 -0.56028370 -0.96112095  0.12460356
#  [61]  0.39978593  0.86426487 -0.47015480  1.95803968 -0.89357142 -0.68692192
#  [67] -0.20713977 -0.08947379  0.83806182 -0.13329947 -0.17727201 -0.64228430
# ...

# %%
n = 100

norms = rnorm(n)
norms

m = mean(norms)
m

s = sd(norms)
s

z = qnorm(.8)
z

left = m - (z * s / sqrt(n))
left
right = m + (z * s / sqrt(n))
right
# Out:
#   [1]  0.11355622  0.25118177  0.20972659  0.33968441 -0.57536941  1.55980579
#   [7] -0.15318342  1.00819531 -1.13306404 -0.24399032  0.44837243 -1.24124360
#  [13]  0.18985074 -0.11915936  0.60725400  0.11482530 -0.36472686  0.61883622
#  [19]  1.04389712  0.20647515 -0.51258378 -0.58443470 -0.10662791 -1.78087840
#  [25]  1.07228681  1.27138127 -1.62254189 -0.06984569 -2.01662149  2.12797437
#  [31]  0.66878379 -0.03203795 -1.74741685  1.00296523 -1.12137082 -1.20593341
#  [37]  0.92429555  0.28557207  1.48028190  1.08408587  0.03804101  2.13404733
#  [43] -0.61054285  0.67232283 -1.95114285 -0.63321538  0.13235022 -0.53399704
#  [49]  0.49421647 -0.13384205  0.44199714  0.01536662 -0.41970675 -0.22839473
#  [55]  0.03938982  1.04509063 -1.16860078  0.73222259 -0.27662071  2.01664838
#  [61] -0.27002062  0.22683114  0.55642920 -2.43117699 -0.77168451 -1.32069137
#  [67]  0.85443944 -2.28368669 -1.15622722 -0.33206117 -0.07843461 -1.23700659
# ...
